# %% [markdown]
# # GAMMA DISTRIBUTION
# A continuous distribution that occurs frequently in applications is called the
# gamma distribution. The name results from its relationship o a function called
# the gamma function.

# %% [markdown]
# The gamma function, denoted by $F$(x) for all x > O, is given by $$F(x) = \int_{0}^{\infty} t^{x-1} e^{-t} dt$$

# %% [markdown]
# ## Gamma Distribution on Python

# %%
import numpy as np
import scipy.stats as stats 
import matplotlib.pyplot as plt

#We'll define three Gamma distributions
x = np.linspace(0, 40, 100)
y1 = stats.gamma.pdf(x, a=5, scale=3)
y2 = stats.gamma.pdf(x, a=2, scale=5)
y3 = stats.gamma.pdf(x, a=4, scale=2)

#and we will add lines for each distribution
plt.plot(x, y1, label='shape=5, scale=3')
plt.plot(x, y2, label='shape=2, scale=5')
plt.plot(x, y3, label='shape=4, scale=2')

plt.legend()
plt.show()
